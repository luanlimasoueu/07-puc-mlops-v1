# %% [markdown]
# ## Instalando o MLflow

# %%
# !pip install mlflow==2.2.2 -q

# %% [markdown]
# ## import das bibliotecas

# %%
import os
import mlflow
import numpy as np

# %% [markdown]
# ## Configurando o MLflow

# %%
MLFLOW_TRACKING_URI = ''
MLFLOW_TRACKING_USERNAME = ''
MLFLOW_TRACKING_PASSWORD = ''
os.environ['MLFLOW_TRACKING_USERNAME'] = MLFLOW_TRACKING_USERNAME
os.environ['MLFLOW_TRACKING_PASSWORD'] = MLFLOW_TRACKING_PASSWORD

mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)

# %%
os.environ['MLFLOW_TRACKING_USERNAME'] = 'renansantosmendes'
os.environ['MLFLOW_TRACKING_PASSWORD'] = '6d730ef4a90b1caf28fbb01e5748f0874fda6077'
mlflow.set_tracking_uri('https://dagshub.com/renansantosmendes/puc_lectures_mlops.mlflow')

# %% [markdown]
# ## Criando um client para comunicar com o registro no DagsHub

# %%
client = mlflow.MlflowClient(tracking_uri=MLFLOW_TRACKING_URI)

# %%
client = mlflow.MlflowClient(tracking_uri='https://dagshub.com/renansantosmendes/puc_lectures_mlops.mlflow')

# %%
client

# %% [markdown]
# ## Recebendo o modelo registrado e suas versões

# %%
registered_model = client.get_registered_model('MODEL_NAME')

# %%
registered_model = client.get_registered_model('fetal_health')

# %%
registered_model.latest_versions
# Out:
# [<ModelVersion: aliases=[], creation_timestamp=1739722475804, current_stage='None', description='', last_updated_timestamp=1739722475804, name='fetal_health', run_id='24577e7cc0b04d0b8f36a442ea400ae2', run_link='', source='mlflow-artifacts:/87bdaa106c21477c9fdd529e09b4447a/24577e7cc0b04d0b8f36a442ea400ae2/artifacts', status='READY', status_message='', tags={}, user_id='', version='51'>]

# %% [markdown]
# ## Obtendo o id da execução do modelo

# %%
run_id = registered_model.latest_versions[-1].run_id

# %% [markdown]
# ## Carregando o modelo

# %%
logged_model = f'runs:/{run_id}/model'
loaded_model = mlflow.pyfunc.load_model(logged_model)
# Out:
# Downloading artifacts:   0%|          | 0/7 [00:00<?, ?it/s]
# 2025/02/16 13:56:29 WARNING mlflow.utils.requirements_utils: Encountered an unexpected error (ValueError("'C:\\\\Users\\\\Luan Lima\\\\AppData\\\\Local\\\\Programs\\\\Python\\\\Python310\\\\Scripts\\\\README.md' is not in the subpath of 'C:\\\\Users\\\\Luan Lima\\\\AppData\\\\Local\\\\Programs\\\\Python\\\\Python310\\\\Lib\\\\site-packages' OR one path is relative and the other is absolute.")) while detecting model dependency mismatches. Set logging level to DEBUG to see the full traceback.
# 2025/02/16 13:56:29 WARNING mlflow.pyfunc: The version of Python that the model was saved in, `Python 3.9.21`, differs from the version of Python that is currently running, `Python 3.10.7`, and may be incompatible
# c:\Users\Luan Lima\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\saving\saving_lib.py:396: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 8 variables whereas the saved optimizer has 14 variables.
#   trackable.load_own_variables(weights_store.get(inner_path))

# %% [markdown]
# ## Fazendo uma predição com o modelo carregadO

# %%
accelerations = 0
fetal_movement = 0
uterine_contractions = 0
severe_decelerations = 0

# %%
received_data = np.array([
        accelerations,
        fetal_movement,
        uterine_contractions,
        severe_decelerations,
    ]).reshape(1, -1)

# %%
received_data
# Out:
# array([[0, 0, 0, 0]])

# %%
loaded_model.predict(received_data)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# array([[0.9738203 , 0.01569601, 0.01048373]], dtype=float32)
